# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Set seed

# %%
np.random.seed(42)

# %% [markdown]
# ## Make random data

# %%
x = np.random.rand(100,1) * 2
y = 4 + 3 * x + np.random.randn(100,1) # y= 4 +3x + noise

# %% [markdown]
# ## Split to train and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Make model

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("slope: ",model.coef_[0][0])
print("intercept : ", model.intercept_[0])
# Out:
# slope:  3.321788957620064
# intercept :  3.7995028620265363

# %% [markdown]
# ## predict x_test

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ## plot real data and regression line

# %%
plt.scatter(x_test, y_test, color="blue", label="real data")
plt.plot(x_test,y_pred, color="red", linewidth=2, label="regression line")
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.title("simple linear regression")
plt.show()

# %%
RMSE = np.sqrt(np.mean(y_test - y_pred)**2)
print(RMSE)
# Out:
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_10096\2126691991.py:1: RuntimeWarning: invalid value encountered in sqrt
#   RMSE = np.sqrt(np.mean(y_test - y_pred))
# np.float64(nan)
